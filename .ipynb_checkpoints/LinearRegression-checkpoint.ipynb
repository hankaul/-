# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

tips = sns.load_dataset("tips")
titanic = sns.load_dataset('titanic')
titanic.dropna(inplace=True)
penguins = sns.load_dataset("penguins")
iris = sns.load_dataset('iris')
dia = sns.load_dataset("diamonds")

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
df = pd.DataFrame(data['data'], columns=data['feature_names'])
df['MEDV'] = data['target']

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('MEDV', 1), df['MEDV'])
# Out:
# C:\Users\asd\AppData\Local\Temp/ipykernel_17912/869316721.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   x_train, x_test, y_train, y_test = train_test_split(df.drop('MEDV', 1), df['MEDV'])

# %%
x_train.shape, x_test.shape
# Out:
# ((379, 13), (127, 13))

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(x_test)

# %%
mse_eval('Linear_R',pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_296/1202978285.py in <module>
# ----> 1 mse_eval('Linear_R',pred,y_test)
#
# ~\AppData\Local\Temp/ipykernel_296/13522614.py in mse_eval(name_, pred, actual)
#      29     plot_predictions(name_, pred, actual)
#      30
# ---> 31     mse = mean_squared_error(pred, actual)
#      32     my_predictions[name_] = mse
#      33
#
# NameError: name 'mean_squared_error' is not defined

# %%
from sklearn.metrics import mean_squared_error

# %%
metrics.mean_squared_error(pred,y_test)
# Out:
# 18.236584398717394

# %%
mse_eval('Linear_R',pred,y_test)
# Out:
#       model        mse
# 0  Linear_R  18.236584

# %%
from sklearn.linear_model import Ridge

# %%
alphas = [100,10,1,0.1,0.01,0.001,0.0001]

# %%
for alpha in alphas:
    ridge= Ridge(alpha=alpha)
    ridge.fit(x_train,y_train)
    pred = ridge.predict(x_test)
mse_eval(f'Ridge(aplpha={alpha})',pred,y_test)
# Out:
#                    model        mse
# 0       Ridge(aplpha=100  18.303206
# 1      Ridge(aplpha=100)  18.303206
# 2               Linear_R  18.236584
# 3    Ridge(aplpha=0.0001  18.236368
# 4   Ridge(aplpha=0.0001)  18.236368
# 5     Ridge(aplpha=0.001  18.234420
# 6    Ridge(aplpha=0.001)  18.234420
# 7      Ridge(aplpha=0.01  18.215244
# 8     Ridge(aplpha=0.01)  18.215244
# 9       Ridge(aplpha=0.1  18.050301
# 10     Ridge(aplpha=0.1)  18.050301
# 11       Ridge(aplpha=10  17.523576
# 12      Ridge(aplpha=10)  17.523576
# 13        Ridge(aplpha=1  17.505126
# 14       Ridge(aplpha=1)  17.505126

# %%
ridge.coef_
# Out:
# array([-1.13497343e-01,  4.42123818e-02,  4.40533664e-02,  3.07631790e+00,
#        -2.20833457e+01,  3.89929214e+00,  8.31587901e-03, -1.57724741e+00,
#         3.46551683e-01, -1.15507260e-02, -1.05551536e+00,  1.02277298e-02,
#        -5.34444210e-01])

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression

# %%
model_R= Ridge(alpha=0)
model =LinearRegression()
model_E = ElasticNet(alpha=0)
model_L= Lasso(alpha=0)

# %%
model_R.fit(x_train,y_train)
model.fit(x_train,y_train)
model_E.fit(x_train,y_train)
model_L.fit(x_train,y_train)
# Out:
# C:\Users\asd\AppData\Local\Temp/ipykernel_17912/1385300835.py:3: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model_E.fit(x_train,y_train)
# C:\Users\asd\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\asd\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4628.534772394086, tolerance: 3.2754046385224274
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\asd\AppData\Local\Temp/ipykernel_17912/1385300835.py:4: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model_L.fit(x_train,y_train)
# ...

# %%
model_R.coef_
# Out:
# array([-1.34191886e-01,  5.31590215e-02, -2.87370709e-02,  3.45447426e+00,
#        -1.80218807e+01,  3.48663059e+00,  3.26618748e-06, -1.59923473e+00,
#         3.75879903e-01, -1.29290785e-02, -8.96069460e-01,  9.21054457e-03,
#        -5.22515741e-01])

# %%
model_L.coef_
# Out:
# array([-1.34191886e-01,  5.31590215e-02, -2.87370709e-02,  3.45447426e+00,
#        -1.80218807e+01,  3.48663059e+00,  3.26618748e-06, -1.59923473e+00,
#         3.75879903e-01, -1.29290785e-02, -8.96069460e-01,  9.21054457e-03,
#        -5.22515741e-01])

# %%
model.coef_
# Out:
# array([-1.34191886e-01,  5.31590215e-02, -2.87370709e-02,  3.45447426e+00,
#        -1.80218807e+01,  3.48663059e+00,  3.26618748e-06, -1.59923473e+00,
#         3.75879903e-01, -1.29290785e-02, -8.96069460e-01,  9.21054457e-03,
#        -5.22515741e-01])

# %%
model_E.coef_
# Out:
# array([-1.34191886e-01,  5.31590215e-02, -2.87370709e-02,  3.45447426e+00,
#        -1.80218807e+01,  3.48663059e+00,  3.26618748e-06, -1.59923473e+00,
#         3.75879903e-01, -1.29290785e-02, -8.96069460e-01,  9.21054457e-03,
#        -5.22515741e-01])

# %%
from sklearn.metrics import mean_squared_error

# %%
for alpha in alphas:
    lasso = Lasso(alpha=alpha)
    lasso.fit(x_train,y_train)
    pred = lasso.predict(x_test)
    mse_eval(f'Lasso(aplpha={alpha})',pred,y_test)
# Out:
#                model        mse
# 0  Lasso(aplpha=100)  55.011049
#                model        mse
# 0  Lasso(aplpha=100)  55.011049
# 1   Lasso(aplpha=10)  31.153392
#                model        mse
# 0  Lasso(aplpha=100)  55.011049
# 1   Lasso(aplpha=10)  31.153392
# 2    Lasso(aplpha=1)  19.515134
#                model        mse
# 0  Lasso(aplpha=100)  55.011049
# 1   Lasso(aplpha=10)  31.153392
# 2    Lasso(aplpha=1)  19.515134
# 3  Lasso(aplpha=0.1)  16.221445
#                 model        mse
# 0   Lasso(aplpha=100)  55.011049
# 1    Lasso(aplpha=10)  31.153392
# 2     Lasso(aplpha=1)  19.515134
# 3   Lasso(aplpha=0.1)  16.221445
# 4  Lasso(aplpha=0.01)  15.422068
#                  model        mse
# 0    Lasso(aplpha=100)  55.011049
# 1     Lasso(aplpha=10)  31.153392
# 2      Lasso(aplpha=1)  19.515134
# 3    Lasso(aplpha=0.1)  16.221445
# 4  Lasso(aplpha=0.001)  15.460413
# 5   Lasso(aplpha=0.01)  15.422068
#                   model        mse
# ...

# %%
ratios = [0.2,0.5,0.8]

# %%
for ratio in ratios:
    elasticnet = ElasticNet(alpha=0.5, l1_ratio=ratio)
    elasticnet.fit(x_train,y_train)
    pred=elasticnet.predict(x_test)
    mse_eval(f'ElasticNet(l1_ratio={ratio}',pred,y_test)
# Out:
#                      model        mse
# 0        Lasso(aplpha=100)  55.011049
# 1         Lasso(aplpha=10)  31.153392
# 2          Lasso(aplpha=1)  19.515134
# 3  ElasticNet(l1_ratio=0.2  18.401368
# 4        Lasso(aplpha=0.1)  16.221445
# 5     Lasso(aplpha=0.0001)  15.468110
# 6      Lasso(aplpha=0.001)  15.460413
# 7       Lasso(aplpha=0.01)  15.422068
#                      model        mse
# 0        Lasso(aplpha=100)  55.011049
# 1         Lasso(aplpha=10)  31.153392
# 2          Lasso(aplpha=1)  19.515134
# 3  ElasticNet(l1_ratio=0.2  18.401368
# 4  ElasticNet(l1_ratio=0.5  18.174907
# 5        Lasso(aplpha=0.1)  16.221445
# 6     Lasso(aplpha=0.0001)  15.468110
# 7      Lasso(aplpha=0.001)  15.460413
# 8       Lasso(aplpha=0.01)  15.422068
#                      model        mse
# 0        Lasso(aplpha=100)  55.011049
# 1         Lasso(aplpha=10)  31.153392
# 2          Lasso(aplpha=1)  19.515134
# 3  ElasticNet(l1_ratio=0.2  18.401368
# 4  ElasticNet(l1_ratio=0.5  18.174907
# ...
