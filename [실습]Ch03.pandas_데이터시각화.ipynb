# %%
import pandas as pd

# %% [markdown]
# ## 샘플 데이터

# %% [markdown]
# [민간 아파트 동향 (clean)](https://bit.ly/ds-house-price-clean)

# %% [markdown]
# ## 데이터프레임 로드

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')

# %%
df
# Out:
#       지역             규모    연도   월   분양가
# 0     서울          60㎡이하  2015  10  5652
# 1     서울    60㎡초과 85㎡이하  2015  10  5882
# 2     서울   85㎡초과 102㎡이하  2015  10  5721
# 3     서울         102㎡초과  2015  10  5879
# 4     인천          60㎡이하  2015  10  3488
# ...   ..            ...   ...  ..   ...
# 3288  경남    60㎡초과 85㎡이하  2020   2  3065
# 3289  경남   85㎡초과 102㎡이하  2020   2  3247
# 3290  제주          60㎡이하  2020   2  4039
# 3291  제주    60㎡초과 85㎡이하  2020   2  3962
# 3292  제주         102㎡초과  2020   2  3601
#
# [3293 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트가 깨지는 현상 해결 방법입니다.

# %% [markdown]
# ### STEP 1. 아래 코드를 실행합니다.

# %%
ㅑ
# Out:
# 지정된 경로를 찾을 수 없습니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7044/1830265017.py in <module>
#       6 fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
#       7 font = fm.FontProperties(fname=fontpath, size=10)
# ----> 8 fm._rebuild()
#       9
#      10 # 그래프에 retina display 적용
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'

# %% [markdown]
# ### STEP 2. 상단 메뉴 - 런타임 - 런타임 다시 시작을 클릭

# %% [markdown]
# ### STEP 3. 아래 코드를 한 번 더 실행 합니다.

# %%
# !apt -qq -y install fonts-nanum > /dev/null

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# 지정된 경로를 찾을 수 없습니다.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7044/1830265017.py in <module>
#       6 fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
#       7 font = fm.FontProperties(fname=fontpath, size=10)
# ----> 8 fm._rebuild()
#       9
#      10 # 그래프에 retina display 적용
#
# AttributeError: module 'matplotlib.font_manager' has no attribute '_rebuild'

# %% [markdown]
# ### STEP 4. 필요한 패키지, 데이터 로딩

# %%
import pandas as pd

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')
df
# Out:
#       지역             규모    연도   월   분양가
# 0     서울          60㎡이하  2015  10  5652
# 1     서울    60㎡초과 85㎡이하  2015  10  5882
# 2     서울   85㎡초과 102㎡이하  2015  10  5721
# 3     서울         102㎡초과  2015  10  5879
# 4     인천          60㎡이하  2015  10  3488
# ...   ..            ...   ...  ..   ...
# 3288  경남    60㎡초과 85㎡이하  2020   2  3065
# 3289  경남   85㎡초과 102㎡이하  2020   2  3247
# 3290  제주          60㎡이하  2020   2  4039
# 3291  제주    60㎡초과 85㎡이하  2020   2  3962
# 3292  제주         102㎡초과  2020   2  3601
#
# [3293 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50577 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### STEP 5. Graph 사이즈 키우는 옵션

# %%
plt.rcParams["figure.figsize"] = (9, 6)

# %% [markdown]
# ## 1. Plot 그래프

# %% [markdown]
# plot은 일반 선그래프를 나타냅니다.

# %%
from matplotlib import rc
import matplotlib.font_manager as fm
#fm._rebuild()
fm.get_fontconfig_fonts()

font_location = './NanumGothic.ttf'

font_name = fm.FontProperties(fname = font_location).get_name()
rc('font',family=font_name)

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')

# %% [markdown]
# kind 옵션:
# * line: 선그래프
# * bar: 바 그래프
# * barh: 수평 바 그래프
# * hist: 히스토그램
# * kde: 커널 밀도 그래프
# * hexbin: 고밀도 산점도 그래프
# * box: 박스 플롯
# * area: 면적 그래프
# * pie: 파이 그래프
# * scatter: 산점도 그래프

# %%
df['분양가'].plot(kind='line')
# Out:
# <AxesSubplot:>

# %% [markdown]
# kind 옵션을 통해 원하는 그래프를 그릴 수 있습니다.

# %% [markdown]
# 데이터의 성격에 맞는 그래프 형식이 있습니다. 앞으로 차근차근 살펴보도록 하겠습니다.

# %% [markdown]
# ## line 그래프

# %% [markdown]
# * line 그래프는 데이터가 연속적인 경우 사용하기 적절합니다. (예를 들면, 주가 데이터)

# %%
# 코드를 입력해 주세요
df.plot()
# Out:
# <AxesSubplot:>

# %%
df_seoul = df.loc[df['지역'] == '서울']

# %%
df_seoul
# Out:
#       지역             규모    연도   월    분양가
# 0     서울          60㎡이하  2015  10   5652
# 1     서울    60㎡초과 85㎡이하  2015  10   5882
# 2     서울   85㎡초과 102㎡이하  2015  10   5721
# 3     서울         102㎡초과  2015  10   5879
# 64    서울          60㎡이하  2015  11   6320
# ...   ..            ...   ...  ..    ...
# 3178  서울         102㎡초과  2020   1   8779
# 3234  서울          60㎡이하  2020   2   8193
# 3235  서울    60㎡초과 85㎡이하  2020   2   8140
# 3236  서울   85㎡초과 102㎡이하  2020   2  13835
# 3237  서울         102㎡초과  2020   2   9039
#
# [212 rows x 5 columns]

# %%
df_seoul_year = df_seoul.groupby('연도')['분양가'].mean()

# %%
df_seoul_year
# Out:
# 연도
# 2015    6201.000000
# 2016    6674.520833
# 2017    6658.729167
# 2018    7054.687500
# 2019    8735.083333
# 2020    9647.375000
# Name: 분양가, dtype: float64

# %%
# 코드를 입력해 주세요
df_seoul_year.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='연도'>

# %% [markdown]
# ## bar 그래프

# %% [markdown]
# bar 그래프는 그룹별로 비교할 때 유용합니다.

# %%
df.groupby('지역')['분양가'].mean()
# Out:
# 지역
# 강원    2448.156863
# 경기    4133.952830
# 경남    2858.932367
# 경북    2570.465000
# 광주    3055.043750
# 대구    3679.620690
# 대전    3176.127389
# 부산    3691.981132
# 서울    7308.943396
# 세종    2983.543147
# 울산    2990.373913
# 인천    3684.302885
# 전남    2326.250000
# 전북    2381.416268
# 제주    3472.677966
# 충남    2534.950000
# 충북    2348.183962
# Name: 분양가, dtype: float64

# %%
# 코드를 입력해 주세요
df.groupby('지역')['분양가'].mean().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='지역'>

# %% [markdown]
# ## 히스토그램 (hist)

# %% [markdown]
# 히스토그램은 **분포-빈도 를 시각화**하여 보여줍니다

# %% [markdown]
# 가로축에는 분포를, 세로축에는 빈도가 시각화되어 보여집니다.

# %%
# 코드를 입력해 주세요
df['분양가'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 커널 밀도 그래프

# %% [markdown]
# * 히스토그램과 유사하게 밀도를 보여주는 그래프입니다.
# * 히스토그램과 유사한 모양새를 갖추고 있습니다.
# * 부드러운 라인을 가지고 있습니다.

# %%
# 코드를 입력해 주세요
df.분양가.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\asd\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## Hexbin

# %% [markdown]
# * hexbin은 고밀도 산점도 그래프입니다.
# * x와 y 키 값을 넣어 주어야 합니다.
# * x, y 값 모두 numeric 한 값을 넣어 주어야합니다.
# * 데이터의 밀도를 추정합니다.

# %%
# 코드를 입력해 주세요
df.plot(kind='hexbin', x='분양가', y='연도',gridsize=20)
# Out:
# <AxesSubplot:xlabel='분양가', ylabel='연도'>

# %% [markdown]
# ## 박스 플롯(box)

# %%
df_seoul = df.loc[df['지역'] == '서울']

# %%
# 코드를 입력해 주세요
df_seoul['분양가'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
from IPython.display import Image

# image source : https://justinsighting.com/how-to-interpret-box-plots/
Image('https://justinsighting.com/wp-content/uploads/2016/12/boxplot-description.png')

# %%
df_seoul.describe()
# Out:
#                연도           월           분양가
# count   212.00000  212.000000    212.000000
# mean   2017.45283    6.566038   7308.943396
# std       1.31439    3.603629   1402.869496
# min    2015.00000    1.000000   5061.000000
# 25%    2016.00000    3.000000   6519.750000
# 50%    2017.00000    7.000000   6895.500000
# 75%    2019.00000   10.000000   7732.000000
# max    2020.00000   12.000000  13835.000000

# %% [markdown]
# IQR은 Inter Quantile Range의 약어로써, (3Q - 1Q) * 1.5 값입니다.

# %%
IQR = (7732 - 6519.75) * 1.5
IQR
# Out:
# 1818.375

# %%
## 박스 플롯 max
7732 + IQR
# Out:
# 9550.375

# %%
## 박스 플롯 min
6519.75 - IQR
# Out:
# 4701.375

# %% [markdown]
# 박스플롯은 데이터 outlier 감지 할 떄 가장 많이 활용 되며, 25%, median, 75% 분위의 값을 활용하는 용도로 많이 활용됩니다.

# %% [markdown]
# ## area plot

# %% [markdown]
# * area plot은 line 그래프에서 아래 area를 모두 색칠해 주는 것이 특징입니다.

# %%
# 코드를 입력해 주세요

# %%
df.groupby('월')['분양가'].count().plot(kind='area')
# Out:
# <AxesSubplot:xlabel='월'>

# %% [markdown]
# ## pie plot (파이 그래프)

# %% [markdown]
# pie는 대표적으로 데이터의 점유율을 보여줄 때 유용합니다.

# %%
# 코드를 입력해 주세요
df.groupby('연도')['분양가'].count().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='분양가'>

# %% [markdown]
# ## scatter plot (산점도 그래프)

# %% [markdown]
# * 점으로 데이터를 표기해 줍니다
# * x, y 값을 넣어주어야합니다 (hexbin과 유사)
# * x축과 y축을 지정해주면 그에 맞는 데이터 분포도를 볼 수 있습니다.
# * 역시 numeric 한 column 만 지정할 수 있습니다

# %%
# 코드를 입력해 주세요
